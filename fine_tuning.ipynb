# %%
import os
import sys
import cv2
from ultralytics import YOLO

# %%
import pandas as pd

splits = {'train': 'data/train-00000-of-00001.parquet', 'test': 'data/test-00000-of-00001.parquet'}
df = pd.read_parquet("hf://datasets/sovitrath/chair_dataset/" + splits["train"])

# %%
df.head(80)

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.yaml")

# Train the model on the COCO8 dataset for 100 epochs
train_results = model.train(
    data="data.yaml",  # Path to dataset configuration file
    epochs=10,  # Number of training epochs
    imgsz=640,  # Image size for training
    device="cpu",  # Device to run on (e.g., 'cpu', 0, [0,1,2,3])
)

# Evaluate the model's performance on the validation set
metrics = model.val()

# Perform object detection on an image
results = model("chairs_data/train/images/test.jpg")  # Predict on an image
results[0].show()  # Display results

# Export the model to ONNX format for deployment
path = model.export(format="onnx")  # Returns the path to the exported model
# Out:
# Ultralytics 8.3.203  Python-3.11.9 torch-2.8.0+cpu CPU (13th Gen Intel Core i7-13700H)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=10, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.yaml, momentum=0.937, mosaic=1.0, multi_scale=False, name=train12, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\hassa\Documents\FYP\runs\detect\train12, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLOv8n summary: 129 layers, 3,011,043 parameters, 3,011,027 gradients, 8.2 GFLOPs
#
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access  (ping: 0.00.0 ms, read: 948.4664.5 MB/s, size: 159.1 KB)
# train: Scanning C:\Users\hassa\Documents\FYP\chairs_data\train\labels.cache... 50 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 51/51 46.3Kit/s 0.0s
# val: Fast image access  (ping: 0.00.0 ms, read: 754.9210.7 MB/s, size: 69.2 KB)
# val: Scanning C:\Users\hassa\Documents\FYP\chairs_data\train\labels.cache... 50 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 51/51  0.0s
# Plotting labels to C:\Users\hassa\Documents\FYP\runs\detect\train12\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to C:\Users\hassa\Documents\FYP\runs\detect\train12
# Starting training for 10 epochs...
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10         0G      2.332      4.403      4.394          3        640: 100% ━━━━━━━━━━━━ 4/4 0.4it/s 10.2s2.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.6it/s 3.1s6.5s
#                    all         51         51    0.00327       0.98     0.0034    0.00111
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/10         0G      2.581      4.308      4.434          3        640: 100% ━━━━━━━━━━━━ 4/4 0.4it/s 9.0s2.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.5it/s 3.9s8.0s
#                    all         51         51    0.00327       0.98    0.00417    0.00122
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/10         0G       2.35      4.069      4.429          3        640: 100% ━━━━━━━━━━━━ 4/4 0.4it/s 11.4s2.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.3it/s 7.7s12.5s
#                    all         51         51    0.00327       0.98    0.00447    0.00131
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/10         0G      2.502      4.071      4.266          3        640: 100% ━━━━━━━━━━━━ 4/4 0.1it/s 29.5s7.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.2it/s 9.7s18.5s
#                    all         51         51    0.00327       0.98     0.0045    0.00132
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/10         0G      2.162      4.175      4.262          3        640: 100% ━━━━━━━━━━━━ 4/4 0.1it/s 27.7s5.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.2it/s 10.6s0.9s
#                    all         51         51     0.0032      0.961    0.00407    0.00105
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/10         0G      2.324      4.034      4.347          3        640: 100% ━━━━━━━━━━━━ 4/4 0.1it/s 29.6s7.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.2it/s 10.9s2.2s
#                    all         51         51    0.00327       0.98    0.00439    0.00134
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/10         0G      2.486      4.087      4.163          3        640: 100% ━━━━━━━━━━━━ 4/4 0.1it/s 29.4s6.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.2it/s 9.7s19.3s
#                    all         51         51    0.00327       0.98     0.0043    0.00127
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/10         0G      2.179      3.989      4.149          4        640: 100% ━━━━━━━━━━━━ 4/4 0.1it/s 27.1s6.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.2it/s 10.1s9.7s
#                    all         51         51    0.00327       0.98    0.00382     0.0011
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/10         0G      2.234      3.917      4.071          3        640: 100% ━━━━━━━━━━━━ 4/4 0.1it/s 28.2s7.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.2it/s 10.8s2.0s
#                    all         51         51     0.0032      0.961    0.00389    0.00119
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/10         0G      2.352       4.01      4.095          3        640: 100% ━━━━━━━━━━━━ 4/4 0.1it/s 27.0s5.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.2it/s 8.9s18.2s
#                    all         51         51     0.0032      0.961     0.0041    0.00128
#
# 10 epochs completed in 0.089 hours.
# Optimizer stripped from C:\Users\hassa\Documents\FYP\runs\detect\train12\weights\last.pt, 6.2MB
# Optimizer stripped from C:\Users\hassa\Documents\FYP\runs\detect\train12\weights\best.pt, 6.2MB
#
# Validating C:\Users\hassa\Documents\FYP\runs\detect\train12\weights\best.pt...
# Ultralytics 8.3.203  Python-3.11.9 torch-2.8.0+cpu CPU (13th Gen Intel Core i7-13700H)
# YOLOv8n summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.2it/s 8.4s16.5s
#                    all         51         51    0.00327       0.98    0.00398     0.0012
# Speed: 2.1ms preprocess, 126.4ms inference, 0.0ms loss, 7.5ms postprocess per image
# Results saved to C:\Users\hassa\Documents\FYP\runs\detect\train12
# Ultralytics 8.3.203  Python-3.11.9 torch-2.8.0+cpu CPU (13th Gen Intel Core i7-13700H)
# YOLOv8n summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.10.1 ms, read: 261.3123.3 MB/s, size: 81.9 KB)
# val: Scanning C:\Users\hassa\Documents\FYP\chairs_data\train\labels.cache... 50 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 51/51 25.4Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 0.4it/s 9.9s4.6ss
#                    all         51         51    0.00327       0.98    0.00398     0.0012
# Speed: 2.0ms preprocess, 149.5ms inference, 0.0ms loss, 9.6ms postprocess per image
# Results saved to C:\Users\hassa\Documents\FYP\runs\detect\train122
#
# image 1/1 c:\Users\hassa\Documents\FYP\chairs_data\train\images\test.jpg: 640x640 (no detections), 549.4ms
# Speed: 37.1ms preprocess, 549.4ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics 8.3.203  Python-3.11.9 torch-2.8.0+cpu CPU (13th Gen Intel Core i7-13700H)
#
# PyTorch: starting from 'C:\Users\hassa\Documents\FYP\runs\detect\train12\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (6.0 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0', 'onnxslim>=0.1.67', 'onnxruntime'] not found, attempting AutoUpdate...
# WARNING Retry 1/2 failed: Command 'pip install --no-cache-dir "onnx>=1.12.0" "onnxslim>=0.1.67" "onnxruntime" ' returned non-zero exit status 1.
